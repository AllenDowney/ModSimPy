# %% [markdown]
# # Modeling and Simulation in Python
#
# Case study: Throwing Axe
#
# Copyright 2017 Allen Downey
#
# License: [Creative Commons Attribution 4.0 International](https://creativecommons.org/licenses/by/4.0)

# %%
# Configure Jupyter so figures appear in the notebook
# %matplotlib inline

# Configure Jupyter to display the assigned value after an assignment
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

# import functions from the modsim.py module
from modsim import *

# %% [markdown]
# ### Throwing axe

# %% [markdown]
# Our favorite event at Lumberjack Competitions is axe throwing.  The axes used for this event typically weigh 1.5 to 2 kg, with handles roughly 0.7 m long.  They are thrown overhead at a target typically 6 m away and 1.5 m off the ground.  Normally, the axe makes one full rotation in the air to hit the target blade first, with the handle close to vertical.
#
# ![Diagram of throwing axe](diagrams/throwingaxe1.png)

# %% [markdown]
# Here's a version of `make_system` that sets the initial conditions.
#
# The state variables are x, y, theta, vx, vy, omega, where theta is the orientation (angle) of the axe in radians and omega is the angular velocity in radians per second.
#
# I chose initial conditions based on videos of axe throwing.

# %%
m = UNITS.meter
s = UNITS.second
kg = UNITS.kilogram
radian = UNITS.radian

def make_system():
    """Makes a System object for the given conditions.
    
    returns: System with init, ...
    """
    P = Vector(0, 2) * m
    V = Vector(8, 4) * m/s
    
    init = State(x=P.x, y=P.y, theta=2, 
                 vx=V.x, vy=V.y, omega=-7)

    t_end = 1.0 * s
    
    return System(init=init, t_end=t_end,
                  g = 9.8 * m/s**2,
                  mass = 1.5 * kg,
                  length = 0.7 * m)

# %% [markdown]
# Let's make a `System`

# %%
system = make_system()
# Out:
# init      x                 0.0 meter
# y                 ...
# t_end                                            1.0 second
# g                                   9.8 meter / second ** 2
# mass                                           1.5 kilogram
# length                                            0.7 meter
# dtype: object

# %%
system.init
# Out:
# x                 0.0 meter
# y                 2.0 meter
# theta                     2
# vx       8.0 meter / second
# vy       4.0 meter / second
# omega                    -7
# dtype: object

# %% [markdown]
# As a simple starting place, I ignore drag, so `vx` and `omega` are constant, and `ay` is just `-g`.

# %%
def slope_func(state, t, system):
    """Computes derivatives of the state variables.
    
    state: State (x, y, x velocity, y velocity)
    t: time
    system: System object with length0, m, k
    
    returns: sequence (vx, vy, ax, ay)
    """
    x, y, theta, vx, vy, omega = state
    unpack(system)

    ax = 0
    ay = -g
    alpha = 0

    return vx, vy, omega, ax, ay, alpha

# %% [markdown]
# As always, let's test the slope function with the initial conditions.

# %%
slope_func(system.init, 0, system)
# Out:
# (8.0 <Unit('meter / second')>,
#  4.0 <Unit('meter / second')>,
#  -7,
#  0,
#  -9.8 <Unit('meter / second ** 2')>,
#  0)

# %% [markdown]
# And then run the simulation.

# %%
results, details = run_ode_solver(system, slope_func, max_step=0.05)
details
# Out:
# sol                                                      None
# t_events                                                   []
# nfev                                                      140
# njev                                                        0
# nlu                                                         0
# status                                                      0
# message     The solver successfully reached the end of the...
# success                                                  True
# dtype: object

# %%
results.tail()
# Out:
#                 x        y    theta vx       vy omega
# 0.831016  6.64813  1.94018 -3.81711  8 -4.14396    -7
# 0.881016  7.04813  1.72074 -4.16711  8 -4.63396    -7
# 0.931016  7.44813  1.47679 -4.51711  8 -5.12396    -7
# 0.981016  7.84813  1.20834 -4.86711  8 -5.61396    -7
# 1.000000        8      1.1       -5  8     -5.8    -7

# %% [markdown]
# ### Visualizing the results

# %% [markdown]
# The simplest way to visualize the results is to plot the state variables as a function of time.

# %%
plot(results.x, label='x')
plot(results.y, label='y')

decorate(xlabel='Time (s)',
         ylabel='Position (m)')

# %%
plot(results.theta, label='theta', color='C2')

decorate(xlabel='Time (s)',
         ylabel='Angle (radian)')

# %% [markdown]
# We can plot the velocities the same way.

# %%
plot(results.vx, label='vx')
plot(results.vy, label='vy')

decorate(xlabel='Time (s)',
         ylabel='Velocity (m/s)')

# %%
plot(results.omega, label='omega', color='C2')

decorate(xlabel='Time (s)',
         ylabel='Angular velocity (rad/s)')

# %% [markdown]
# Another way to visualize the results is to plot y versus x.  The result is the trajectory through the plane of motion.

# %%
plot(results.x, results.y, label='trajectory', color='C3')

decorate(xlabel='x position (m)',
         ylabel='y position (m)')

# %% [markdown]
# ## Exercises
#
# **Exercise:**  Find the starting conditions that make the final height of the COG as close as possible to 1.5 m.  Ideally, the final angle should be a little past vertical.

# %% [markdown]
# **Exercise:**  Compute the total velocity of the leading edge of the axe at the point of impact, that is, the sum of velocity due to translation and rotation.

# %%
def make_frame(theta):
    rhat = Vector(pol2cart(theta, 1))
    that = rhat.perp()
    return rhat, that

# %%
# quick, get those state variables into Vector objects!
state = get_last_value(results)
x, y, theta, vx, vy, omega = state
P = Vector(x, y)
V = Vector(vx, vy)
rhat, that = make_frame(theta)

# %%
# Solution

decorate(xlabel='x position (m)',
         ylabel='y position (m)',
         xlim=[7, 9],
         ylim=[0, 1.5],
         legend=False)

# plot the handle
# l1 and l2 are the lengths of the handle below and above
# the center of gravity (COG)
l1 = 0.6
l2 = 0.1
A = P - l1 * rhat
B = P + l2 * rhat
plot_segment(A, B, color='red', update=True)

# plot the axe head
C = B + l2 * that
D = B - l2 * that
plot_segment(C, D, color='black', linewidth=10, update=True)

# plot the COG
plot(x, y, 'bo', update=True)
    
plot_segment(P, D, color='green', linewidth=1, update=True)

# compute the velocity of point D due to rotation
R = D - P
VrotD = omega * R.perp()

plot_segment(D, D+VrotD, color='orange', linewidth=1, update=True)

# add in the velocity due to translation
Vtot = VrotD + V
plot_segment(D, D+Vtot, color='purple', linewidth=1, update=True)

# print the magnitude of velocity at the point of contact
Vtot.mag
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-37b0db207e65> in <module>
#      14 A = P - l1 * rhat
#      15 B = P + l2 * rhat
# ---> 16 plot_segment(A, B, color='red', update=True)
#      17
#      18 # plot the axe head
#
# ~/anaconda3/envs/ModSimPy/lib/python3.7/site-packages/modsim/modsim.py in plot_segment(A, B, **options)
#    1352     xs = A.x, B.x
#    1353     ys = A.y, B.y
# -> 1354     plot(xs, ys, **options)
#
# ~/anaconda3/envs/ModSimPy/lib/python3.7/site-packages/modsim/modsim.py in plot(*args, **options)
#     699         lines = plt.plot(x, y, style, **options)
#     700     else:
# --> 701         lines = plt.plot(x, y, **options)
#     702     return lines
#     703
#
# ~/anaconda3/envs/ModSimPy/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# ~/anaconda3/envs/ModSimPy/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ~/anaconda3/envs/ModSimPy/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~/anaconda3/envs/ModSimPy/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     403                 "non-matching shapes is deprecated.")
#     404         for j in range(max(ncx, ncy)):
# --> 405             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     406             ret.append(seg)
#     407         return ret
#
# ~/anaconda3/envs/ModSimPy/lib/python3.7/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     310         default_dict = self._getdefaults(set(), kw)
#     311         self._setdefaults(default_dict, kw)
# --> 312         seg = mlines.Line2D(x, y, **kw)
#     313         return seg
#     314
#
# ~/anaconda3/envs/ModSimPy/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     402         # update kwargs before updating data to give the caller a
#     403         # chance to init axes (and hence unit support)
# --> 404         self.update(kwargs)
#     405         self.pickradius = pickradius
#     406         self.ind_offset = 0
#
# ~/anaconda3/envs/ModSimPy/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     955
#     956         with cbook._setattr_cm(self, eventson=False):
# --> 957             ret = [_update_property(self, k, v) for k, v in props.items()]
#     958
#     959         if len(ret):
#
# ~/anaconda3/envs/ModSimPy/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     955
#     956         with cbook._setattr_cm(self, eventson=False):
# --> 957             ret = [_update_property(self, k, v) for k, v in props.items()]
#     958
#     959         if len(ret):
#
# ~/anaconda3/envs/ModSimPy/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     951                 if not callable(func):
#     952                     raise AttributeError('{!r} object has no property {!r}'
# --> 953                                          .format(type(self).__name__, k))
#     954                 return func(v)
#     955
#
# AttributeError: 'Line2D' object has no property 'update'

# %% [markdown]
# ## Animation
#
# NOTE: This section needs to be updated.
#
# Animating this system is a little more complicated, if we want to show the shape and orientation of the axe.
#
# It is useful to construct a frame with $\hat{r}$ along the handle of the axe and $\hat{\theta}$ perpendicular.

# %% [markdown]
# Now we're ready to animate the results.  The following figure shows the frame and the labeled points A, B, C, and D.
#
# ![Diagram of the axe with reference frame](diagrams/throwingaxe2.png)

# %%
decorate(xlabel='x position (m)',
         ylabel='y position (m)',
         xlim=[0, 8.1],
         ylim=[0, 5.5],
         legend=False)



for t, state in system.results.iterrows():
    x, y, theta, vx, vy, omega = state
    P = Vector(x, y)
    rhat, that = make_frame(theta)
    
    # plot the handle
    A = P - l1 * rhat
    B = P + l2 * rhat
    plot_segment(A, B, color='red', update=True)

    # plot the axe head
    C = B + l2 * that
    D = B - l2 * that
    plot_segment(C, D, color='black', linewidth=10, update=True)

    # plot the COG
    plot(x, y, 'bo', update=True)
    sleep(0.01)
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %% [markdown]
# During the animation, the parts of the axe seem to slide around relative to each other.  I think that's because the lines and circles get rounded off to the nearest pixel.
#
# Here's the final state of the axe at the point of impact (assuming the target is 8 m away).

# %%
state
# Out:
# x        8.0
# y        1.1
# theta   -5.0
# vx       8.0
# vy      -5.8
# omega   -7.0
# Name: 1.0, dtype: float64
